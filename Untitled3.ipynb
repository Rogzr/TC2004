# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/content/drive/MyDrive/AA-Datasets/alphabet_stock_data.csv')

# %%
df
# Out:
#           Date         Open         High          Low        Close  \
# 0   2020-04-01  1122.000000  1129.689941  1097.449951  1105.619995
# 1   2020-04-02  1098.260010  1126.859985  1096.400024  1120.839966
# 2   2020-04-03  1119.015015  1123.540039  1079.810059  1097.880005
# 3   2020-04-06  1138.000000  1194.660034  1130.939941  1186.920044
# 4   2020-04-07  1221.000000  1225.000000  1182.229980  1186.510010
# ..         ...          ...          ...          ...          ...
# 122 2020-09-24  1411.030029  1443.708984  1409.849976  1428.290039
# 123 2020-09-25  1432.630005  1450.000000  1413.339966  1444.959961
# 124 2020-09-28  1474.209961  1476.800049  1449.301025  1464.520020
# 125 2020-09-29  1470.390015  1476.662964  1458.805054  1469.329956
# 126 2020-09-30  1466.800049  1489.750000  1459.880005  1469.599976
#
#        Adj Close   Volume
# 0    1105.619995  2343100
# 1    1120.839966  1964900
# 2    1097.880005  2313400
# 3    1186.920044  2664700
# ...

# %%
df['Date'] = pd.to_datetime(df['Date'])
df2= df[(df['Date'] >= "2020-04-01") & (df['Date']<= "2020-04-30")]
df2.set_index('Date', inplace=True)
df2.head()
# Out:
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2020-04-01  1122.000000  1129.689941  1097.449951  1105.619995  1105.619995
# 2020-04-02  1098.260010  1126.859985  1096.400024  1120.839966  1120.839966
# 2020-04-03  1119.015015  1123.540039  1079.810059  1097.880005  1097.880005
# 2020-04-06  1138.000000  1194.660034  1130.939941  1186.920044  1186.920044
# 2020-04-07  1221.000000  1225.000000  1182.229980  1186.510010  1186.510010
#
#              Volume
# Date
# 2020-04-01  2343100
# 2020-04-02  1964900
# 2020-04-03  2313400
# 2020-04-06  2664700
# 2020-04-07  2387300

# %%
plt.plot(df2['Close'])
plt.title("Alphabet Inc. shares")
plt.xlabel('Fechas')
plt.ylabel('Precio')
# Out:
# Text(0, 0.5, 'Precio')
